# %% [markdown]
# # 데이터 정제

# %%
import pandas as pd
import sys
import pprint as pp
from collections import defaultdict

input_file = "wellness_data.tsv"

users = []
chatbots = defaultdict(list)
idx = 1
cnt = 0
same_flag = False

with open(input_file, 'r') as f:
    for line in f.readlines():
        category, user, chatbot = line.split('\t')
        users.append(user.strip())
        chatbot = chatbot.strip()

        if chatbot != "":
            if not same_flag:
                idx = cnt
                same_flag = True
            chatbots[idx].append(chatbot)
        elif same_flag:
            same_flag = False
        cnt += 1

for i in range(len(users)):
    if i in chatbots:
        chats = chatbots[i]

    for chat in chats:
        print(users[i], chat, sep = '\t')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 그러자니 굳이 서울로 다시 갈 필요가 없을 것 같았어요.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 그러자니 굳이 서울로 다시 갈 필요가 없을 것 같았어요.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 왜 나는 나를 컨트롤하지 못할까.	그러시군요. 그 다음은 어떻게 됐나요?
# 왜 나는 나를 컨트롤하지 못할까.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 왜 나는 나를 컨트롤하지 못할까.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 처음부터 그랬던 것 아니야.	그러시군요. 그 다음은 어떻게 됐나요?
# 처음부터 그랬던 것 아니야.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 처음부터 그랬던 것 아니야.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 겉은 건강해 보이는데 말이야.	그러시군요. 그 다음은 어떻게 됐나요?
# 겉은 건강해 보이는데 말이야.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 겉은 건강해 보이는데 말이야.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 너무 이상한 날이었는데.	그러시군요. 그 다음은 어떻게 됐나요?
# 너무 이상한 날이었는데.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 너무 이상한 날이었는데.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 그 뒤론 그 병원에선 나를 치료 안 해주더라.	그러시군요. 그 다음은 어떻게 됐나요?
# 그 뒤론 그 병원에선 나를 치료 안 해주더라.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 그 뒤론 그 병원에선 나를 치료 안 해주더라.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 나는 보여.	그러시군요. 그 다음은 어떻게 됐나요?
# 나는 보여.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 나는 보여.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 내 나이는 34살이야.	그러시군요. 그 다음은 어떻게 됐나요?
# 내 나이는 34살이야.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 내 나이는 34살이야.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 너는 잘 모르겠지만 실제로 그래.	그러시군요. 그 다음은 어떻게 됐나요?
# 너는 잘 모르겠지만 실제로 그래.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 너는 잘 모르겠지만 실제로 그래.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 내가 그냥 호기심에 친구 따라 술집을 갔는데 그걸 들켜서…	그러시군요. 그 다음은 어떻게 됐나요?
# 내가 그냥 호기심에 친구 따라 술집을 갔는데 그걸 들켜서…	헉, 그래서요? 뒷 이야기가 궁금해요!
# 내가 그냥 호기심에 친구 따라 술집을 갔는데 그걸 들켜서…	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 근데 그걸 유명 연예인이 가져간 거예요.	그러시군요. 그 다음은 어떻게 됐나요?
# 근데 그걸 유명 연예인이 가져간 거예요.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 근데 그걸 유명 연예인이 가져간 거예요.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 딱히 뭘 등록하기도 전이었으니까 그냥… 뺏긴 거죠.	그러시군요. 그 다음은 어떻게 됐나요?
# 딱히 뭘 등록하기도 전이었으니까 그냥… 뺏긴 거죠.	헉, 그래서요? 뒷 이야기가 궁금해요!
# 딱히 뭘 등록하기도 전이었으니까 그냥… 뺏긴 거죠.	와, 정말요? 그래서 그 후에는 어떻게 됐나요?
# 나도 내가 언제부터 이렇게 됐는지 잘 기억이 안 나.	그러시군요. 그 다음은 어떻게 됐나요?
# 나도 내가 언제부터 이렇게 됐는지 잘 기억이 안 나.	헉, 그래서요? 뒷 이야기가 궁금해요!
#
# 저를 보호해주려고 미행을 붙인 거 아닐까요?	하지만 아닐 수도 있지 않을까요?
# 저주가 묻어있는 느낌이야.	와, 정말요? 진짜인가요?
# 저주가 묻어있는 느낌이야.	그렇군요. 그 다음에는 어떻게 되었나요?
# 저주가 묻어있는 느낌이야.	하지만 아닐 수도 있지 않을까요?
# 성령이 내 몸에 들어오는 거거든.	와, 정말요? 진짜인가요?
# 성령이 내 몸에 들어오는 거거든.	그렇군요. 그 다음에는 어떻게 되었나요?
# 성령이 내 몸에 들어오는 거거든.	하지만 아닐 수도 있지 않을까요?
# 나를 지켜주려고 경호원을 보낸 것 같기도 하고 청혼하려고 이벤트를 준비하는 것 같기도 했어.	와, 정말요? 진짜인가요?
# 나를 지켜주려고 경호원을 보낸 것 같기도 하고 청혼하려고 이벤트를 준비하는 것 같기도 했어.	그렇군요. 그 다음에는 어떻게 되었나요?
# 나를 지켜주려고 경호원을 보낸 것 같기도 하고 청혼하려고 이벤트를 준비하는 것 같기도 했어.	하지만 아닐 수도 있지 않을까요?
# 저도 제가 대단한 것 같아요.	와, 정말요? 진짜인가요?
# 저도 제가 대단한 것 같아요.	그렇군요. 그 다음에는 어떻게 되었나요?
# 저도 제가 대단한 것 같아요.	하지만 아닐 수도 있지 않을까요?
# 하지만 하느님이 나를 진정시켜줬어.	와, 정말요? 진짜인가요?
# 하지만 하느님이 나를 진정시켜줬어.	그렇군요. 그 다음에는 어떻게 되었나요?
# 하지만 하느님이 나를 진정시켜줬어.	하지만 아닐 수도 있지 않을까요?
# 오전 수업을 들으려면 8시에는 일어나야 하는데, 엄마가 깨우지 않으면 일어나지도 못해요.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 오전 수업을 들으려면 8시에는 일어나야 하는데, 엄마가 깨우지 않으면 일어나지도 못해요.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 오전 수업을 들으려면 8시에는 일어나야 하는데, 엄마가 깨우지 않으면 일어나지도 못해요.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 수업 빠지면 뭐… 아침에 내내 잠만 자는 거지.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 수업 빠지면 뭐… 아침에 내내 잠만 자는 거지.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 수업 빠지면 뭐… 아침에 내내 잠만 자는 거지.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 그리고 하루 동안 몰아서 12시간 넘게 잠만 자요.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 그리고 하루 동안 몰아서 12시간 넘게 잠만 자요.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 그리고 하루 동안 몰아서 12시간 넘게 잠만 자요.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 하루에 12시간은 자는 거 같아.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 하루에 12시간은 자는 거 같아.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 하루에 12시간은 자는 거 같아.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 자취하고서 아침에 못 일어나는 날이 많았어.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 자취하고서 아침에 못 일어나는 날이 많았어.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 자취하고서 아침에 못 일어나는 날이 많았어.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 이틀 연속 잠만 자는 날도 많아. 오죽하면 별명이 잠만보야.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 이틀 연속 잠만 자는 날도 많아. 오죽하면 별명이 잠만보야.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 이틀 연속 잠만 자는 날도 많아. 오죽하면 별명이 잠만보야.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
# 진짜 무슨 누가 목 쳐서 기절이라도 시킨 것처럼 잠만 자거든.	현실이 너무 힘들면 잠을 오래 자는 경우가 있다고 해요. 혹시 힘든 일이 있으신가요?
# 진짜 무슨 누가 목 쳐서 기절이라도 시킨 것처럼 잠만 자거든.	너무 많이 자는 것도 건강에 좋지 않답니다. 조금 줄여 보는 건 어떨까요?
# 진짜 무슨 누가 목 쳐서 기절이라도 시킨 것처럼 잠만 자거든.	고민이 많으면 잠을 과하게 잘 수도 있다던데 제가 같이 고민해드릴까요?
#
일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 병원에서 검사해봐도 이상이 없다고 하는데..뭐가 문제인지 모르겠어.	이상이 없다고 하니 다행이에요.
# 병원에서 검사해봐도 이상이 없다고 하는데..뭐가 문제인지 모르겠어.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 병원에서 검사해봐도 이상이 없다고 하는데..뭐가 문제인지 모르겠어.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 너무 놀라서 조퇴하고 병원에 갔는데 그냥 신경성이라고 별문제가 없다고 하더라구.	이상이 없다고 하니 다행이에요.
# 너무 놀라서 조퇴하고 병원에 갔는데 그냥 신경성이라고 별문제가 없다고 하더라구.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 너무 놀라서 조퇴하고 병원에 갔는데 그냥 신경성이라고 별문제가 없다고 하더라구.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 새가슴이라 그렇다고 하는데…검사를 해보면 별 문제는 없다고 하더라구요.	이상이 없다고 하니 다행이에요.
# 새가슴이라 그렇다고 하는데…검사를 해보면 별 문제는 없다고 하더라구요.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 새가슴이라 그렇다고 하는데…검사를 해보면 별 문제는 없다고 하더라구요.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 병원 가면 아무 이상이 없다고 하는데…진짜 너무 아프거든.	이상이 없다고 하니 다행이에요.
# 병원 가면 아무 이상이 없다고 하는데…진짜 너무 아프거든.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 병원 가면 아무 이상이 없다고 하는데…진짜 너무 아프거든.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 주변에서 병원에 가보라고 해서 검사도 받아봤는데 모든게 정상이라고 하더라구요.	이상이 없다고 하니 다행이에요.
# 주변에서 병원에 가보라고 해서 검사도 받아봤는데 모든게 정상이라고 하더라구요.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 주변에서 병원에 가보라고 해서 검사도 받아봤는데 모든게 정상이라고 하더라구요.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 병원 가서 다시 검사를 받아봐도 이상이 없다고 하지.	이상이 없다고 하니 다행이에요.
# 병원 가서 다시 검사를 받아봐도 이상이 없다고 하지.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 병원 가서 다시 검사를 받아봐도 이상이 없다고 하지.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 근데 검사 다 해봤는데 아무 이상이 없다는 거야.	이상이 없다고 하니 다행이에요.
# 근데 검사 다 해봤는데 아무 이상이 없다는 거야.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 근데 검사 다 해봤는데 아무 이상이 없다는 거야.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 다른 문제가 있나 해서 다른 과 가서 검사 많이 해봤는데 다 이상은 없대요.	이상이 없다고 하니 다행이에요.
# 다른 문제가 있나 해서 다른 과 가서 검사 많이 해봤는데 다 이상은 없대요.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 다른 문제가 있나 해서 다른 과 가서 검사 많이 해봤는데 다 이상은 없대요.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 이상이 있는 것 같아서 검사를 받아는데. 이상이 없다고 해서 더 이상했어요.	이상이 없다고 하니 다행이에요.
# 이상이 있는 것 같아서 검사를 받아는데. 이상이 없다고 해서 더 이상했어요.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 이상이 있는 것 같아서 검사를 받아는데. 이상이 없다고 해서 더 이상했어요.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 가서 검사를 했는데 아무 이상이 없대.	이상이 없다고 하니 다행이에요.
# 가서 검사를 했는데 아무 이상이 없대.	다행이네요. 후에 다시 증상이 나타나신다면 꼭 병원을 찾아 주세요.
# 가서 검사를 했는데 아무 이상이 없대.	일단 아무 이상이 없다고 하니 그것만으로도 정말 감사한 일이네요.
# 좋다고 하는 병원들은 다 찾아갔거든?	그렇군요. 병원에서는 뭐라고 하던가요?
# 좋다고 하는 병원들은 다 찾아갔거든?	두려우실 수도 있는데 병원을 찾는 것만으로도 큰 용기라고 생각해요.
# 좋다고 하는 병원들은 다 찾아갔거든?	진료를 받으셨군요. 병원에서는 어떤 처방을 내려주셨나요?
#
	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 그 후에 너무 놀라서 병원을 갔는데 딱히 이상은 없댔어요.	휴, 다행이네요.
# 그 후에 너무 놀라서 병원을 갔는데 딱히 이상은 없댔어요.	일단 이상이 없다고 하니 정말 다행이네요.
# 그 후에 너무 놀라서 병원을 갔는데 딱히 이상은 없댔어요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 혹시 몸에 무슨 문제가 있는 건가 해서 병원 갔는데 이상 없대요.	휴, 다행이네요.
# 혹시 몸에 무슨 문제가 있는 건가 해서 병원 갔는데 이상 없대요.	일단 이상이 없다고 하니 정말 다행이네요.
# 혹시 몸에 무슨 문제가 있는 건가 해서 병원 갔는데 이상 없대요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 병원에서는 별 이상 없다고 그러더라고요.	휴, 다행이네요.
# 병원에서는 별 이상 없다고 그러더라고요.	일단 이상이 없다고 하니 정말 다행이네요.
# 병원에서는 별 이상 없다고 그러더라고요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 그런데 의사 선생님은 저 보고 아무 이상이 없다는 거예요.	휴, 다행이네요.
# 그런데 의사 선생님은 저 보고 아무 이상이 없다는 거예요.	일단 이상이 없다고 하니 정말 다행이네요.
# 그런데 의사 선생님은 저 보고 아무 이상이 없다는 거예요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 병원을 두 군데나 갔는데 신경성이라는 말만 듣고 나왔어요.	휴, 다행이네요.
# 병원을 두 군데나 갔는데 신경성이라는 말만 듣고 나왔어요.	일단 이상이 없다고 하니 정말 다행이네요.
# 병원을 두 군데나 갔는데 신경성이라는 말만 듣고 나왔어요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 그럴 리가 없을 것 같아서 다른 병원도 가봤는데 진짜 괜찮다더라?	휴, 다행이네요.
# 그럴 리가 없을 것 같아서 다른 병원도 가봤는데 진짜 괜찮다더라?	일단 이상이 없다고 하니 정말 다행이네요.
# 그럴 리가 없을 것 같아서 다른 병원도 가봤는데 진짜 괜찮다더라?	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 병원에선 이상이 없다고 하는데 너무 피곤해.	휴, 다행이네요.
# 병원에선 이상이 없다고 하는데 너무 피곤해.	일단 이상이 없다고 하니 정말 다행이네요.
# 병원에선 이상이 없다고 하는데 너무 피곤해.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 예전에 부모님이 걱정하셔서 병원을 갔었는데 딱히 문제는 없댔거든요.	휴, 다행이네요.
# 예전에 부모님이 걱정하셔서 병원을 갔었는데 딱히 문제는 없댔거든요.	일단 이상이 없다고 하니 정말 다행이네요.
# 예전에 부모님이 걱정하셔서 병원을 갔었는데 딱히 문제는 없댔거든요.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 그래서 병원을 갔는데 이상이 없대.	휴, 다행이네요.
# 그래서 병원을 갔는데 이상이 없대.	일단 이상이 없다고 하니 정말 다행이네요.
# 그래서 병원을 갔는데 이상이 없대.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 이상해서 다른 병원도 몇 군데 가봤는데 다들 이상이 없다는 거야.	휴, 다행이네요.
# 이상해서 다른 병원도 몇 군데 가봤는데 다들 이상이 없다는 거야.	일단 이상이 없다고 하니 정말 다행이네요.
# 이상해서 다른 병원도 몇 군데 가봤는데 다들 이상이 없다는 거야.	좋은 일이네요. 후에 다시 증상이 발생하면 꼭 병원을 찾아 주세요.
# 다행히 주변 사람들이 신고를 해줘서 응급실로 바로 갔어요.	헉, 응급실에 가셨군요. 지금은 괜찮으신가요?
#
정말 힘드시겠어요. 지금도 증상이 심하신가요?
# 자고 나면 괜찮을 줄 알았는데 비슷해…	너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 지금도 상태가 계속 안 좋아.	상태가 더 안 좋아지셨군요. 걱정이 되네요.
# 지금도 상태가 계속 안 좋아.	정말 힘드시겠어요. 지금도 증상이 심하신가요?
# 지금도 상태가 계속 안 좋아.	너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 이게 제 마음과 상관없이 증상이 계속 나타나요.	상태가 더 안 좋아지셨군요. 걱정이 되네요.
# 이게 제 마음과 상관없이 증상이 계속 나타나요.	정말 힘드시겠어요. 지금도 증상이 심하신가요?
# 이게 제 마음과 상관없이 증상이 계속 나타나요.	너무 심하시면 병원을 다시 가보는 건 어떨까요?
# 나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.	상태가 더 안 좋아지셨군요. 걱정이 되네요.
# 나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.	정말 힘드시겠어요. 지금도 증상이 심하신가요?
# 나이 들면 고쳐질 줄 알았는데…아직까지 계속 그래요.	너무 심하시면 병원을 다시 가보는 건 어떨까요?

# %%
import openpyxl
import random
from openpyxl import Workbook, load_workbook
from kobert_transformers import get_tokenizer
from kogpt2_transformers import get_kogpt2_tokenizer
def tweet_dialog_dataset():
  root_path = "../data"
  tweet_file = root_path + "/tweeter_dialog_dataset.xlsx"
  tweet_file_output = root_path + "/tweeter_dialog_data.txt"

  f = open(tweet_file_output, 'w')

  wb = load_workbook(filename=tweet_file)

  ws = wb[wb.sheetnames[0]]
  # print(sheet)
  for row in ws.iter_rows():
    for cell in row:
      if cell.value == None:
        break
      # print(cell.value)
      f.write(cell.value + "\n")
    # print("\n\n\n")
    f.write("\n\n\n")

  f.close()


  
def wellness_question_data():
  wellness_file ="wellness_dialog_data.xlsx"
  wellness_q_output = "wellness_dialog_question.txt"

  f = open(wellness_q_output, 'w')

  wb = load_workbook(filename=wellness_file)

  ws = wb[wb.sheetnames[0]]
  # print(sheet)
  for row in ws.iter_rows():
    f.write(row[0].value +"\t" + row[1].value + "\n")

  f.close()

def wellness_answer_data():
  wellness_file ="wellness_dialog_data.xlsx"
  wellness_a_output = "wellness_dialog_answer.txt"

  f = open(wellness_a_output, 'w')
  wb = load_workbook(filename=wellness_file)
  ws = wb[wb.sheetnames[0]]

  for row in ws.iter_rows():
    if row[2].value == None:
      continue
    else:
      f.write(row[0].value + "\t" + row[2].value + "\n")
  f.close()

def category_data():
  data_path ="wellness_dialog_question.txt"
  c_output ="wellness_dialog_category.txt"

  i_f = open(data_path, 'r')
  o_f = open(c_output, 'w')

  category_count = 0
  flag = True

  cate_dict = []
  i_lines = i_f.readlines()
  for i, data in enumerate(i_lines):
    tmp = data.split("\t")
    a = tmp[0]
    if a not in cate_dict:
      cate_dict.append(a)
      o_f.write(a.strip() +"\t"+ str(category_count) +"\n")
      category_count += 1
  o_f.close()
  i_f.close()

def wellness_text_classification_data():
  wellness_category_file ="wellness_dialog_category.txt"
  wellness_question_file = "wellness_dialog_question.txt"
  wellness_text_classification_file = "wellness_dialog_for_text_classification.txt"

  cate_file = open(wellness_category_file, 'r')
  ques_file = open(wellness_question_file, 'r')
  text_classfi_file = open(wellness_text_classification_file, 'w')

  category_lines = cate_file.readlines()
  cate_dict = {}
  for line_num, line_data in enumerate(category_lines):
    data = line_data.split("\t")
    cate_dict[data[0]] = data[1][:-1]
  print(cate_dict)

  ques_lines = ques_file.readlines()
  ques_dict = {}
  for line_num, line_data in enumerate(ques_lines):
    data = line_data.split("\t")
    # print(data[1]+ "    " + cate_dict[data[0]])
    text_classfi_file.write(data[1][:-1] + "    " + cate_dict[data[0]] + "\n")

  cate_file.close()
  ques_file.close()
  text_classfi_file.close()



def wellness_dialog_for_autoregressive():
  root_path = "../data"
  wellness_file = root_path + "/wellness_dialog_dataset.xlsx"
  wellness_answer_file = root_path + "/wellness_dialog_answer.txt"
  wellness_question_file = root_path + "/wellness_dialog_question.txt"
  wellness_autoregressive_file = root_path + "/wellness_dialog_for_autoregressive.txt"


  answ_file = open(wellness_answer_file, 'r')
  ques_file = open(wellness_question_file, 'r')
  autoregressive_file = open(wellness_autoregressive_file, 'w')

  answ_lines = answ_file.readlines()
  ques_lines = ques_file.readlines()
  ques_dict = {}
  for line_num, line_data in enumerate(ques_lines):
    ques_data = line_data.split('    ')
    for ans_line_num, ans_line_data in enumerate(answ_lines):
      ans_data = ans_line_data.split('    ')
      if ques_data[0] == ans_data[0]:
        autoregressive_file.write(ques_data[1][:-1] + "    " + ans_data[1])
      else:
        continue

  answ_file.close()
  ques_file.close()
  autoregressive_file.close()

def tweet_data_for_autoregressive():
  root_path = "../data"

  # wellness_autoregressive_file = root_path+"/wellness_dialog_for_autoregressive.txt"
  # wellness_text_classification_file = root_path + "/wellness_dialog_for_text_classification.txt"
  file_path = root_path + "/tweeter_dialog_data.txt"
  tweeter_autoregressive_file = root_path + "/tweeter_dialog_for_autoregressive.txt"

  data_file = open(file_path, 'r')
  tweet_file = open(tweeter_autoregressive_file, 'w')

  data_file_lines = data_file.readlines()
  dialog = ''
  for line_num, line_data in enumerate(data_file_lines):
    if line_data == "\n" and dialog != '':
      dialog += "\n"
      tweet_file.write(dialog)
      print(dialog)
      dialog = ''
    elif line_data != "\n":
      dialog += "<s>" + line_data[:-1] + "</s>"
  data_file.close()
  tweet_file.close()

def seperate_wellness_data():
  # wellness_autoregressive_file = root_path+"/wellness_dialog_for_autoregressive.txt"
  # wellness_text_classification_file = root_path + "/wellness_dialog_for_text_classification.txt"
  file_path = root_path + "/wellness_dialog_for_autoregressive.txt"
  train_file_path = root_path + "/wellness_dialog_for_autoregressive_train.txt"
  test_file_path = root_path + "/wellness_dialog_for_autoregressive_test.txt"

  sperated_file = open(file_path, 'r')
  train_file = open(train_file_path, 'w')
  test_file = open(test_file_path, 'w')

  sperated_file_lines = sperated_file.readlines()
  ques_dict = {}
  for line_num, line_data in enumerate(sperated_file_lines):
    rand_num = random.randint(0, 10)
    if rand_num < 10:
      train_file.write(line_data)
    else:
      test_file.write(line_data)

  sperated_file.close()
  train_file.close()
  test_file.close()

def tweeter_autoregressive_data():
  root_path = "../data"
  tokenizer =get_kogpt2_tokenizer()
  # wellness_autoregressive_file = root_path+"/wellness_dialog_for_autoregressive.txt"
  # wellness_text_classification_file = root_path + "/wellness_dialog_for_text_classification.txt"
  file_path = root_path + "/tweeter_dialog_data.txt"
  tweeter_autoregressive_file = root_path + "/tweeter_dialog_for_autoregressive.txt"

  data_file = open(file_path, 'r')
  tweet_file = open(tweeter_autoregressive_file, 'w')

  data_file_lines = data_file.readlines()
  dialog = ''
  max_len=0
  for line_num, line_data in enumerate(data_file_lines):
    if line_data == "\n" and dialog != '':
      dialog += "\n"
      tweet_file.write(dialog)
      print(dialog)
      dialog = ''
    elif line_data != "\n":
      tmp_data = dialog + "<s>" + line_data[:-1] + "</s>"
      if len(tokenizer.encode(tmp_data))>= 1024:
        continue
      else:
        max_len= max(len(tokenizer.encode(tmp_data)),max_len)
        dialog = tmp_data
  print('max_token_length: ', max_len)
  data_file.close()
  tweet_file.close()

def tweeter_autoregressive_data_with_token():
  root_path = "../data"
  wellness_file = root_path + "/wellness_dialog_dataset.xlsx"
  wellness_answer_file = root_path + "/wellness_dialog_answer.txt"
  wellness_question_file = root_path + "/wellness_dialog_question.txt"
  wellness_autoregressive_file = root_path + "/wellness_dialog_for_autoregressive_with_token.txt"

  answ_file = open(wellness_answer_file, 'r')
  ques_file = open(wellness_question_file, 'r')
  autoregressive_file = open(wellness_autoregressive_file, 'w')

  answ_lines = answ_file.readlines()
  ques_lines = ques_file.readlines()
  ques_dict = {}
  for line_num, line_data in enumerate(ques_lines):
    ques_data = line_data.split('    ')
    for ans_line_num, ans_line_data in enumerate(answ_lines):
      ans_data = ans_line_data.split('    ')
      if ques_data[0] == ans_data[0]:
        autoregressive_file.write("<s>" + ques_data[1][:-1] + "</s><s>" + ans_data[1][:-1] + "</s>\n")
      else:
        continue

  answ_file.close()
  ques_file.close()
  autoregressive_file.close()

def merge_data():
  root_path = "../data"

  chatbot_file = root_path + "/chatbot_data.tsv"
  wellness_file = root_path + "/wellness_dialog.tsv"

  total_data_file = root_path + "/a_chatbot_wellness_data.tsv"

  chatbot_f = open(chatbot_file, 'r')
  wellness_f = open(wellness_file, 'r')
  output_f = open(total_data_file, 'w')

  chatbot_lines = chatbot_f.readlines()
  for line_num, line_data in enumerate(chatbot_lines):
    output_f.write(line_data)

  wellness_lines = wellness_f.readlines()
  for line_num, line_data in enumerate(wellness_lines):
    output_f.write(line_data)

  chatbot_f.close()
  wellness_f.close()
  output_f.close()

if __name__ == "__main__":
  file_path = "wellness_data.tsv"
  o_path = "chatbot_wellness_data_for_autoregressive.txt"

  i_file = open(file_path, 'r')
  o_file = open(o_path, 'w')

  i_lines = i_file.readlines()
  for i, data in enumerate(i_lines):
    if(i == 0):
      continue;
    tmp = data.split('\t')
    question = tmp[0]
    answer = tmp[1][:-1]
    o_file.write("<s>" + question + "</s><s>" + answer+ "</s>\n")
  wellness_question_data()
  wellness_answer_data()
  category_data()
  wellness_text_classification_data()
  
  #wellness_text_classification_data()
# Out:
가': '129', '배경/남편/의심': '130', '배경/남편/의지': '131', '배경/남편/폭력': '132', '배경/대인관계': '133', '배경/대인관계/갈등': '134', '배경/대인관계/양호': '135', '배경/대인관계/협소': '136', '배경/대학': '137', '배경/대학/실패': '138', '배경/대학/실패/재수': '139', '배경/대학/입학': '140', '배경/대학/재수': '141', '배경/대학/휴학': '142', '배경/문제': '143', '배경/문제/과음': '144', '배경/문제/머리카락/털뽑기': '145', '배경/문제/불면': '146', '배경/문제/불안감/소변': '147', '배경/문제/불편감/옷': '148', '배경/문제/소변': '149', '배경/문제/알코올의존': '150', '배경/부모': '151', '배경/부모/가출/아버지': '152', '배경/부모/갈등': '153', '배경/부모/갈등/아버지': '154', '배경/부모/관계소원': '155', '배경/부모/무관심': '156', '배경/부모/싸움': '157', '배경/부모/아버지': '158', '배경/부모/아버지/죽음': '159', '배경/부모/아버지/폭력': '160', '배경/부모/어머니/죽음': '161', '배경/부모/이혼': '162', '배경/부모/죽음': '163', '배경/사고': '164', '배경/사고/교통사고': '165', '배경/사업': '166', '배경/사업/경제적문제/실패': '167', '배경/사업/남편/동업자': '168', '배경/사업/실패': '169', '배경/생활': '170', '배경/생활/불가능/운전': '171', '배경/생활/스트레스': '172', '배경/생활/양호': '173', '배경/생활/여행/해외': '174', '배경/생활/운동': '175', '배경/생활/자연소멸/증상': '176', '배경/생활/취미': '177', '배경/생활/폭행/피해': '178', '배경/생활/해외': '179', '배경/생활/혼자': '180', '배경/생활/휴식': '181', '배경/성격': '182', '배경/성격/극단적': '183', '배경/성격/급함': '184', '배경/성격/내성적': '185', '배경/성격/소심': '186', '배경/성격/예민함': '187', '배경/성격/완벽추구': '188', '배경/성격/욕심많음': '189', '배경/성격/자기중심적': '190', '배경/성격/자립적': '191', '배경/시댁': '192', '배경/시댁/갈등': '193', '배경/시댁/갈등/시어머니': '194', '배경/시댁/경제적문제': '195', '배경/아르바이트': '196', '배경/애완동물': '197', '배경/애완동물/가족/갈등': '198', '배경/어린시절': '199', '배경/어린시절/가난': '200', '배경/여자친구': '201', '배경/여자친구/관계소원': '202', '배경/여자친구/동거': '203', '배경/여자친구/이별': '204', '배경/연애': '205', '배경/연애/이별': '206', '배경/유학': '207', '배경/육아/힘듦': '208', '배경/음주': '209', '배경/음주/과음': '210', '배경/음주/알코올의존': '211', '배경/음주/애주가': '212', '배경/음주/자주': '213', '배경/이사': '2 ...

# %%
# !nvidia-smi
# Out:
# Mon Nov  1 13:30:54 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.29.05    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    33W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kobert-transformers==0.4.1
# !pip install kogpt2-transformers==0.3.0
# !pip install transformers==3.0.2
# !pip install torch
# !pip install tokenizers==0.8.1rc1
# !pip install kss
# !pip install flask
# !pip install flask_restful
# Out:
# Requirement already satisfied: kobert-transformers==0.4.1 in /usr/local/lib/python3.7/dist-packages (0.4.1)
# Requirement already satisfied: transformers>=2.9.1 in /usr/local/lib/python3.7/dist-packages (from kobert-transformers==0.4.1) (3.0.2)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from kobert-transformers==0.4.1) (1.9.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.1.0->kobert-transformers==0.4.1) (3.7.4.3)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (0.8.1rc1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (4.62.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (3.3.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (0.1.96)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (0.0.46)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (21.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=2.9.1->kobert-transformers==0.4.1) (2.23.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=2.9.1->kobert-transformers==0.4.1) (2.4.7)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=2.9.1->kobert-transformers==0.4.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=2.9.1->kobert-transformers==0.4.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=2.9.1->kobert-transformers==0.4.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=2.9.1->kobert-transformers==0.4.1) (2021.5.30)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=2.9.1->kobert-transformers==0.4.1) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=2.9.1->kobert-transformers==0.4.1) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=2.9.1->kobert-transformers==0.4.1) (7.1.2)
# Requirement already satisfied: kogpt2-transformers==0.3.0 in /usr/local/lib/python3.7/dist-packages (0.3.0)
# Requirement already satisfied: tokenizers>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from kogpt2-transformers==0.3.0) (0.8.1rc1)
# Requirement already satisfied: torch>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from kogpt2-transformers==0.3.0) (1.9.0+cu111)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from kogpt2-transformers==0.3.0) (3.0.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.1.0->kogpt2-transformers==0.3.0) (3.7.4.3)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (0.0.46)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (2.23.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (4.62.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (1.19.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (2019.12.20)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (21.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (0.1.96)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers>=3.0.0->kogpt2-transformers==0.3.0) (3.3.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers>=3.0.0->kogpt2-transformers==0.3.0) (2.4.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->kogpt2-transformers==0.3.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->kogpt2-transformers==0.3.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->kogpt2-transformers==0.3.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers>=3.0.0->kogpt2-transformers==0.3.0) (2021.5.30)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.0.0->kogpt2-transformers==0.3.0) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.0.0->kogpt2-transformers==0.3.0) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers>=3.0.0->kogpt2-transformers==0.3.0) (7.1.2)
# Requirement already satisfied: transformers==3.0.2 in /usr/local/lib/python3.7/dist-packages (3.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2019.12.20)
# Requirement already satisfied: sentencepiece!=0.1.92 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (0.1.96)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (21.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (3.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (1.19.5)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (0.0.46)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (0.8.1rc1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers==3.0.2) (4.62.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers==3.0.2) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers==3.0.2) (1.15.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.9.0+cu111)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.7.4.3)
# Requirement already satisfied: tokenizers==0.8.1rc1 in /usr/local/lib/python3.7/dist-packages (0.8.1rc1)
# Requirement already satisfied: kss in /usr/local/lib/python3.7/dist-packages (3.3.1.1)
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (from kss) (1.6.1)
# Requirement already satisfied: flask in /usr/local/lib/python3.7/dist-packages (1.1.4)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)
# Requirement already satisfied: flask_restful in /usr/local/lib/python3.7/dist-packages (0.3.9)
# Requirement already satisfied: Flask>=0.8 in /usr/local/lib/python3.7/dist-packages (from flask_restful) (1.1.4)
# Requirement already satisfied: aniso8601>=0.82 in /usr/local/lib/python3.7/dist-packages (from flask_restful) (9.0.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from flask_restful) (2018.9)
# Requirement already satisfied: six>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from flask_restful) (1.15.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful) (7.1.2)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful) (2.11.3)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful) (1.0.1)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask>=0.8->flask_restful) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask>=0.8->flask_restful) (2.0.1)

# %%
import sys
sys.path.append('drive/My Drive/Colab Notebooks/')
sys.path.append('drive/My Drive/Colab Notebooks/dialogLM')

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from IPython.display import display
from tqdm import tqdm

import torch
from transformers import (
  AdamW,
  ElectraConfig,
  ElectraTokenizer
)
from torch.utils.data import dataloader
#from dialogLM.dataloader.wellness import WellnessTextClassificationDataset
#from dialogLM.model.koelectra import koElectraForSequenceClassification
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.electra.configuration_electra'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-027ec956ba97> in <module>()
#       7
#       8 import torch
# ----> 9 from transformers import (
#      10   AdamW,
#      11   ElectraConfig,
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _get_module(self, module_name)
#
# RuntimeError: Failed to import transformers.models.electra.configuration_electra because of the following error (look up to see its traceback):
# No module named 'transformers.models.electra.configuration_electra'

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# !nvidia-smi
# Out:
# Thu Nov  4 05:34:11 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    32W / 149W |      3MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
def train(epoch, model, optimizer, train_loader, save_step, save_ckpt_path, train_step = 0):
    losses = []
    train_start_index = train_step+1 if train_step != 0 else 0
    total_train_step = len(train_loader)
    model.train()

    with tqdm(total= total_train_step, desc=f"Train({epoch})") as pbar:
        pbar.update(train_step)
        for i, data in enumerate(train_loader, train_start_index):
            optimizer.zero_grad()

            '''
            inputs = {'input_ids': batch[0],
                      'attention_mask': batch[1],
                      'bias_labels': batch[3],
                      'hate_labels': batch[4]}
            if self.args.model_type != 'distilkobert':
              inputs['token_type_ids'] = batch[2]
            '''
            inputs = {'input_ids': data['input_ids'],
                      'attention_mask': data['attention_mask'],
                      'labels': data['labels']
                      }
            outputs = model(**inputs)

            loss = outputs[0]

            losses.append(loss.item())

            loss.backward()
            optimizer.step()

            pbar.update(1)
            pbar.set_postfix_str(f"Loss: {loss.item():.3f} ({np.mean(losses):.3f})")

            if i >= total_train_step or i % save_step == 0:
                torch.save({
                    'epoch': epoch,  # 현재 학습 epoch
                    'model_state_dict': model.state_dict(),  # 모델 저장
                    'optimizer_state_dict': optimizer.state_dict(),  # 옵티마이저 저장
                    'loss': loss.item(),  # Loss 저장
                    'train_step': i,  # 현재 진행한 학습
                    'total_train_step': len(train_loader)  # 현재 epoch에 학습 할 총 train step
                }, save_ckpt_path)

    return np.mean(losses)

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset # 데이터로더

from kogpt2_transformers import get_kogpt2_tokenizer
from kobert_transformers import get_tokenizer

class WellnessAutoRegressiveDataset(Dataset):
  """Wellness Auto Regressive Dataset"""

  def __init__(self,
               file_path = "wellness_dialog_for_text_classification.txt",
               n_ctx = 1024
               ):
    self.file_path = file_path
    self.data =[]
    self.tokenizer = get_kogpt2_tokenizer()


    bos_token_id = [self.tokenizer.bos_token_id]
    eos_token_id = [self.tokenizer.eos_token_id]
    pad_token_id = [self.tokenizer.pad_token_id]
    file = open(self.file_path, 'r', encoding='utf-8')

    while True:
      line = file.readline().strip()
      if not line:
        break
      datas = line.split("    ")

      index_of_words = bos_token_id +self.tokenizer.encode(datas[0]) + eos_token_id + bos_token_id + self.tokenizer.encode(datas[1][:-1])+ eos_token_id
      pad_token_len = n_ctx - len(index_of_words)

      index_of_words += pad_token_id * pad_token_len

      self.data.append(index_of_words)

    file.close()

  def __len__(self):
    return len(self.data)

  def __getitem__(self,index):
    item = self.data[index]
    return item

class WellnessTextClassificationDataset(Dataset):
  """Wellness Text Classification Dataset"""
  def __init__(self,
               file_path = "wellness_dialog_for_text_classification.txt",
               num_label = 359,
               device = 'cpu',
               max_seq_len = 512, # KoBERT max_length
               tokenizer = None
               ):
    self.file_path = file_path
    self.device = device
    self.data =[]
    self.tokenizer = tokenizer if tokenizer is not None else get_tokenizer()


    file = open(self.file_path, 'r', encoding='utf-8')

    while True:
      line = file.readline()
      if not line:
        break
      datas = line.split("    ")
      index_of_words = self.tokenizer.encode(datas[0])
      token_type_ids = [0] * len(index_of_words)
      attention_mask = [1] * len(index_of_words)

      # Padding Length
      padding_length = max_seq_len - len(index_of_words)

      # Zero Padding
      index_of_words += [0] * padding_length
      token_type_ids += [0] * padding_length
      attention_mask += [0] * padding_length

      # Label
      if datas[1][:-1] == '':
        break
      label = int(datas[1][:-1])

      data = {
              'input_ids': torch.tensor(index_of_words).to(self.device),
              'token_type_ids': torch.tensor(token_type_ids).to(self.device),
              'attention_mask': torch.tensor(attention_mask).to(self.device),
              'labels': torch.tensor(label).to(self.device)
             }

      self.data.append(data)

    file.close()

  def __len__(self):
    return len(self.data)
  def __getitem__(self,index):
    item = self.data[index]
    return item

if __name__ == "__main__":
  dataset = WellnessAutoRegressiveDataset()
  dataset2 = WellnessTextClassificationDataset()
  print(dataset)
  print(dataset2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-23c7ee94b64b> in <module>()
#     102
#     103 if __name__ == "__main__":
# --> 104   dataset = WellnessAutoRegressiveDataset()
#     105   dataset2 = WellnessTextClassificationDataset()
#     106   print(dataset)
#
# <ipython-input-24-23c7ee94b64b> in __init__(self, file_path, n_ctx)
#      15     self.file_path = file_path
#      16     self.data =[]
# ---> 17     self.tokenizer = get_kogpt2_tokenizer()
#      18
#      19
#
# /usr/local/lib/python3.7/dist-packages/kogpt2_transformers/load_model.py in get_kogpt2_tokenizer(model_path)
#      10 def get_kogpt2_tokenizer(model_path=None):
#      11     if not model_path:
# ---> 12         model_path = 'taeminlee/kogpt2'
#      13     tokenizer = KoGPT2TokenizerFast.from_pretrained(model_path)
#      14     return tokenizer
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in from_pretrained(cls, pretrained_model_name_or_path, *init_inputs, **kwargs)
#    1748         stride: int = 0,
#    1749         is_pretokenized: bool = False,
# -> 1750         pad_to_multiple_of: Optional[int] = None,
#    1751         return_tensors: Optional[Union[str, TensorType]] = None,
#    1752         return_token_type_ids: Optional[bool] = None,
#
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py in _from_pretrained(cls, resolved_vocab_files, pretrained_model_name_or_path, init_configuration, use_auth_token, *init_inputs, **kwargs)
#    1793         the mask for sequence classification and the overflowing elements if a ``max_length`` is specified.
#    1794
# -> 1795         Args:
#    1796             batch_text_or_text_pairs (:obj:`List[str]`,  :obj:`List[Tuple[str, str]]`,
#    1797                                       :obj:`List[List[str]]`,  :obj:`List[Tuple[List[str], List[str]]]`,
#
# ModuleNotFoundError: No module named 'transformers.models.auto.configuration_auto'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import torch
import torch.nn as nn
from torch.nn import CrossEntropyLoss, MSELoss
from transformers.activations import get_activation
from transformers import (
  ElectraPreTrainedModel,
  ElectraModel,
  ElectraConfig,
  ElectraTokenizer,
  BertConfig,
  BertTokenizer
)

# MODEL_CLASSES = {
#     "koelectra-base": (ElectraConfig, koElectraForSequenceClassification, ElectraTokenizer),
#     "koelectra-small": (ElectraConfig, koElectraForSequenceClassification, ElectraTokenizer),
#     "koelectra-base-v2": (ElectraConfig, koElectraForSequenceClassification, ElectraTokenizer),
#     "koelectra-small-v2": (ElectraConfig, koElectraForSequenceClassification, ElectraTokenizer),
# }


# def load_tokenizer(args):
#   return MODEL_CLASSES[args.model_type][2].from_pretrained(args.model_name_or_path)


class ElectraClassificationHead(nn.Module):
  """Head for sentence-level classification tasks."""

  def __init__(self, config, num_labels):
    super().__init__()
    self.dense = nn.Linear(config.hidden_size, 4*config.hidden_size)
    self.dropout = nn.Dropout(config.hidden_dropout_prob)
    self.out_proj = nn.Linear(4*config.hidden_size,num_labels)

  def forward(self, features, **kwargs):
    x = features[:, 0, :]  # take <s> token (equiv. to [CLS])
    x = self.dropout(x)
    x = self.dense(x)
    x = get_activation("gelu")(x)  # although BERT uses tanh here, it seems Electra authors used gelu here
    x = self.dropout(x)
    x = self.out_proj(x)
    return x

class koElectraForSequenceClassification(ElectraPreTrainedModel):
  def __init__(self,
               config,
               num_labels):
    super().__init__(config)
    self.num_labels = num_labels
    self.electra = ElectraModel(config)
    self.classifier = ElectraClassificationHead(config, num_labels)

    self.init_weights()
  def forward(
          self,
          input_ids=None,
          attention_mask=None,
          token_type_ids=None,
          position_ids=None,
          head_mask=None,
          inputs_embeds=None,
          labels=None,
          output_attentions=None,
          output_hidden_states=None,
  ):
    r"""
    labels (:obj:`torch.LongTensor` of shape :obj:`(batch_size,)`, `optional`, defaults to :obj:`None`):
        Labels for computing the sequence classification/regression loss.
        Indices should be in :obj:`[0, ..., config.num_labels - 1]`.
        If :obj:`config.num_labels == 1` a regression loss is computed (Mean-Square loss),
        If :obj:`config.num_labels > 1` a classification loss is computed (Cross-Entropy).
    """
    discriminator_hidden_states = self.electra(
      input_ids,
      attention_mask,
      token_type_ids,
      position_ids,
      head_mask,
      inputs_embeds,
      output_attentions,
      output_hidden_states,
    )

    sequence_output = discriminator_hidden_states[0]
    logits = self.classifier(sequence_output)

    outputs = (logits,) + discriminator_hidden_states[1:]  # add hidden states and attention if they are here

    if labels is not None:
      if self.num_labels == 1:
        #  We are doing regression
        loss_fct = MSELoss()
        loss = loss_fct(logits.view(-1), labels.view(-1))
      else:
        loss_fct = CrossEntropyLoss()
        loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1))
      outputs = (loss,) + outputs

    return outputs  # (loss), (logits), (hidden_states), (attentions)

def koelectra_input(tokenizer, str, device = None, max_seq_len = 512):
  index_of_words = tokenizer.encode(str)
  # token_type_ids = [0] * len(index_of_words)
  attention_mask = [1] * len(index_of_words)

  # Padding Length
  padding_length = max_seq_len - len(index_of_words)

  # Zero Padding
  index_of_words += [0] * padding_length
  # token_type_ids += [0] * padding_length
  attention_mask += [0] * padding_length

  data = {
    'input_ids': torch.tensor([index_of_words]).to(device),
    'attention_mask': torch.tensor([attention_mask]).to(device),
  }
  return data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _get_module(self, module_name)
#
# /usr/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'transformers.models.electra.modeling_electra'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-b7a4da6369d6> in <module>()
#       3 from torch.nn import CrossEntropyLoss, MSELoss
#       4 from transformers.activations import get_activation
# ----> 5 from transformers import (
#       6   ElectraPreTrainedModel,
#       7   ElectraModel,
#
# /usr/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in __getattr__(self, name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _get_module(self, module_name)
#
# RuntimeError: Failed to import transformers.models.electra.modeling_electra because of the following error (look up to see its traceback):
# No module named 'transformers.models.electra.modeling_electra'

# %%
import gc

gc.collect()
torch.cuda.empty_cache()
data_path = "wellness_dialog_for_text_classification.txt"
checkpoint_path =f"checkpoint"
save_ckpt_path = f"koelectra-wellnesee-text-classification.pth"
model_name_or_path = "monologg/koelectra-base-discriminator"


n_epoch = 50          # Num of Epoch
batch_size = 2      # 배치 사이즈
ctx = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(ctx)
save_step = 100 # 학습 저장 주기
learning_rate = 5e-6  # Learning Rate

# Electra Tokenizer
tokenizer = ElectraTokenizer.from_pretrained(model_name_or_path)

# WellnessTextClassificationDataset 데이터 로더
dataset = WellnessTextClassificationDataset(file_path=data_path, tokenizer=tokenizer, device=device)
train_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=True)

electra_config = ElectraConfig.from_pretrained(model_name_or_path)
model = koElectraForSequenceClassification.from_pretrained(pretrained_model_name_or_path=model_name_or_path,
                                                            config=electra_config,
                                                            num_labels=359)
model.to(device)

# Prepare optimizer and schedule (linear warmup and decay)
no_decay = ['bias', 'LayerNorm.weight']
optimizer_grouped_parameters = [
    {'params': [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
      'weight_decay': 0.01},
    {'params': [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
optimizer = AdamW(optimizer_grouped_parameters, lr=learning_rate)

pre_epoch, pre_loss, train_step = 0, 0, 0
if os.path.isfile(save_ckpt_path):
    checkpoint = torch.load(save_ckpt_path, map_location=device)
    pre_epoch = checkpoint['epoch']
    pre_loss = checkpoint['loss']
    train_step =  checkpoint['train_step']
    total_train_step =  checkpoint['total_train_step']

    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

    print(f"load pretrain from: {save_ckpt_path}, epoch={pre_epoch}, loss={pre_loss}")
    # best_epoch += 1

losses = []
offset = pre_epoch
for step in range(n_epoch):
    epoch = step + offset
    loss = train( epoch, model, optimizer, train_loader, save_step, save_ckpt_path, train_step)
    losses.append(loss)

# data
data = {
    "loss": losses
}
df = pd.DataFrame(data)
display(df)

# graph
plt.figure(figsize=[12, 4])
plt.plot(losses, label="loss")
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-26-44e223a96c1b> in <module>()
#       1 import gc
# ----> 2 import ElectraTokenizer
#       3 gc.collect()
#       4 torch.cuda.empty_cache()
#       5 data_path = "wellness_dialog_for_text_classification.txt"
#
# ModuleNotFoundError: No module named 'ElectraTokenizer'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
